# %% [markdown]
# <a href="https://colab.research.google.com/github/pnrajucse/NASSCOM-AI-TRAINING/blob/main/Matplotlib_%26_Seaborn_Exercise_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
plt.figure(figsize=(8,5))
plt.hist(tips['total_bill'], bins=20, edgecolor='black')

plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill ($)')
plt.ylabel('Frequency')

plt.show()

# %%
smoker_counts = tips['smoker'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    smoker_counts,
    labels=smoker_counts.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Proportion of Smokers vs Non-Smokers')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=tips,
    x='total_bill',
    y='tip',
    hue='smoker'
)

plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    data=tips,
    x='day',
    y='total_bill'
)

plt.title('Average Total Bill by Day')
plt.xlabel('Day')
plt.ylabel('Average Total Bill ($)')

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    data=tips,
    y='time',
    x='tip',
    orient='h'
)

plt.title('Average Tip by Time')
plt.xlabel('Average Tip ($)')
plt.ylabel('Time')

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Top-left: Histogram of tip
axes[0, 0].hist(tips['tip'], bins=20, edgecolor='black')
axes[0, 0].set_title('Distribution of Tips')
axes[0, 0].set_xlabel('Tip ($)')
axes[0, 0].set_ylabel('Frequency')

# Top-right: Box plot of total_bill by sex
sns.boxplot(
    data=tips,
    x='sex',
    y='total_bill',
    ax=axes[0, 1]
)
axes[0, 1].set_title('Total Bill by Gender')

# Bottom-left: Count plot of day
sns.countplot(
    data=tips,
    x='day',
    ax=axes[1, 0]
)
axes[1, 0].set_title('Customer Count by Day')

# Bottom-right: Swarm plot of tip by smoker
sns.swarmplot(
    data=tips,
    x='smoker',
    y='tip',
    ax=axes[1, 1]
)
axes[1, 1].set_title('Tip by Smoker Status')

plt.tight_layout()
plt.show()
print("\n--- Exercise Complete! ---")
print("You've practiced creating various plots and interpreting their insights.")
print("Remember that good EDA often involves iterative plotting and questioning.")
# Out:
# --- Exercise Complete! ---
# You've practiced creating various plots and interpreting their insights.
# Remember that good EDA often involves iterative plotting and questioning.
